# %%
import monai

monai.config.print_config()
# Out:
# MONAI version: 0.4.0+9.g36b8302
# Numpy version: 1.19.2
# Pytorch version: 1.7.0
# MONAI flags: HAS_EXT = True, USE_COMPILED = False
# MONAI rev id: 36b8302f206104c3743197c5d624badb2806f239
#
# Optional dependencies:
# Pytorch Ignite version: 0.4.2
# Nibabel version: 3.1.1
# scikit-image version: 0.17.2
# Pillow version: 8.0.1
# Tensorboard version: 2.3.0
# gdown version: 3.12.2
# TorchVision version: 0.8.1
# ITK version: 5.2.0
# tqdm version: 4.51.0
# lmdb version: NOT INSTALLED or UNKNOWN VERSION.
# psutil version: 5.7.2
#
# For details about installing the optional dependencies, please visit:
#     https://docs.monai.io/en/latest/installation.html#installing-the-recommended-dependencies

# %%
# Include numpy for pi
import numpy as np

# Include monai applications: which are collections of data already allocated to training, testing, and/or validation sets
from monai.apps import DecathlonDataset

# Include monai's standard data loader
from monai.data import DataLoader

# Include transforms that are used to normalize and augment data as part of the training workflow
from monai.transforms import \
    LoadImageD, LoadNiftiD, AsChannelFirstD, AsChannelLastD, AddChannelD, ScaleIntensityD, ToTensorD, Compose, \
    AsDiscreteD, SpacingD, OrientationD, ResizeD, RandAffineD, ThresholdIntensityD

# Enable deterministic training for python, numpy and pytorh
monai.utils.set_determinism(seed=0, additional_settings=None)

# Specify where the collections of downloaded data should be stored on the local filesystem
root_dir = "./"

# The training transform is a composition of transforms that manipulate the images and labels (segmentation truth) as a
#    data processing pipeline.
train_transform = Compose([                   # These are the transforms to be associated with the training data
    LoadImageD(keys=["image","label"]),          # The Decathlan data has images and labels, and both should be loaded
    AsChannelFirstD("image"),                    # The first dimenion of the 4D image specifies the data channel: e.g., T1 or T2
    AddChannelD("label"),                        # Then we associate the ideal segmentations with each image
    SpacingD(keys=["image","label"], pixdim=(1., 1., 1.), mode=('bilinear', 'nearest')),   # images and labels are resmpled to
                                                                                           #   isotropic, 1x1x1mm voxels
    OrientationD(keys=["image","label"], axcodes='RAS'),                        # Images and labels are oriented into RAS space
    ScaleIntensityD(keys=["image"]),                                            # Each image's intensities are normalized 0 to 1
    ThresholdIntensityD(keys=["label"], threshold=0.5, above=False, cval=1),    # We reduced the labels from 3 classes to 2,
                                                                                #   by thresholding keeping background as 0, and
                                                                                #   reassigning labels 1 and 2 as 1.
    RandAffineD(keys=["image","label"], spatial_size=(-1, -1, -1),   # When an image is requested for training, with probability
                rotate_range=(0, 0, np.pi/8),                        #   of 1, it will be rotated in the z-axis, scaled in every
                scale_range=(0.1, 0.1, 0.1),                         #   axis, and resamples using bilinary interpolation for 
                mode=('bilinear', 'nearest'),                        #   images and nearest neighbor interpolation for labels
                prob=1.0),
    ToTensorD(keys=["image","label"]),                               # Images and labels are then exported as tensors
])

# The  training data is defined as Task 05 from the Decathlon challenge.  The DecathlonDataset knows the data's location on the
#   web and its MD5 checksum.  We specify where it should be stored on the local filesystem. Furthermore, we specify that the 
#   data should be processed using the training transforms defined above, before being provided to a MONAI network. 
#   Via Datasets, data preparation is managed separately from the details of network training.  This separation enables the 
#   sharing of standard training data and the clear (reproducible) definition of data pre-processing and augmentation steps.
#   Note that a dataset is merely a definition.  The actual data downloading and processing occurs with the data loader 
#   command (next).   Additionally, datasets optionally offer caching of intermediate results, and other optimization 
#   specifications.
train_dataset = DecathlonDataset(root_dir=root_dir, task="Task05_Prostate", section="training", \
                                 transform=train_transform, download=True)

# The data is the downloaded, MD5 verified, processed, and cached as specified by the dataset
train_data_loader = DataLoader(train_dataset, batch_size=1, shuffle=True, num_workers=0)
# Out:
#   0%|                                                   | 0/26 [00:00<?, ?it/s]
# Verified 'Task05_Prostate.tar', md5: 35138f08b1efaef89d7424d2bcc928db.
# file ./Task05_Prostate.tar exists, skip downloading.
# extracted file ./Task05_Prostate exists, skip extracting.
# Modifying image pixdim from [0.625   0.625   3.60001 1.     ] to [  0.625        0.625        3.60000992 151.21210251]
#   4%|█▋                                         | 1/26 [00:00<00:15,  1.64it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  148.64025265]
#   8%|███▎                                       | 2/26 [00:01<00:14,  1.64it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  162.36758282]
#  12%|████▉                                      | 3/26 [00:01<00:13,  1.66it/s]Modifying image pixdim from [0.6249999 0.6249999 3.6       1.       ] to [  0.62499988   0.62499988   3.5999999  152.06272679]
#  15%|██████▌                                    | 4/26 [00:02<00:13,  1.68it/s]Modifying image pixdim from [0.62499976 0.62499976 3.6        1.        ] to [  0.62499976   0.62499976   3.5999999  164.74616031]
#  19%|████████▎                                  | 5/26 [00:02<00:12,  1.68it/s]Modifying image pixdim from [0.75 0.75 4.   1.  ] to [  0.75         0.75         4.00000005 134.2148206 ]
#  23%|█████████▉                                 | 6/26 [00:03<00:11,  1.74it/s]Modifying image pixdim from [0.625      0.62500006 3.6000001  1.        ] to [  0.625        0.62500005   3.60000016 168.35859116]
#  27%|███████████▌                               | 7/26 [00:04<00:11,  1.64it/s]Modifying image pixdim from [0.75       0.74999964 2.9999986  1.        ] to [  0.75         0.74999965   2.99999861 157.50724574]
#  31%|█████████████▏                             | 8/26 [00:04<00:09,  1.82it/s]Modifying image pixdim from [0.6       0.5999997 3.999998  1.       ] to [  0.60000002   0.59999975   3.99999799 117.82332812]
#  35%|██████████████▉                            | 9/26 [00:05<00:08,  1.92it/s]Modifying image pixdim from [0.6       0.5999997 3.999998  1.       ] to [  0.60000002   0.59999975   3.99999799 129.0477496 ]
#  38%|████████████████▏                         | 10/26 [00:05<00:08,  1.97it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  154.70488398]
#  42%|█████████████████▊                        | 11/26 [00:06<00:08,  1.83it/s]Modifying image pixdim from [0.6        0.60000014 4.0000005  1.        ] to [  0.60000002   0.60000017   4.00000043 128.8161199 ]
#  46%|███████████████████▍                      | 12/26 [00:06<00:07,  1.89it/s]Modifying image pixdim from [0.75      0.7500001 4.0000005 1.       ] to [  0.75         0.75000013   4.00000043 128.6789431 ]
#  50%|█████████████████████                     | 13/26 [00:07<00:06,  1.97it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  160.67573396]
#  54%|██████████████████████▌                   | 14/26 [00:07<00:06,  1.81it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  170.38896694]
#  58%|████████████████████████▏                 | 15/26 [00:08<00:06,  1.71it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  180.81811432]
#  62%|█████████████████████████▊                | 16/26 [00:09<00:06,  1.64it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625       0.625       3.5999999 152.3814254]
#  65%|███████████████████████████▍              | 17/26 [00:09<00:05,  1.61it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  202.45334114]
#  69%|█████████████████████████████             | 18/26 [00:10<00:05,  1.59it/s]Modifying image pixdim from [0.6        0.60000014 4.0000005  1.        ] to [  0.60000002   0.60000017   4.00000041 174.1516677 ]
#  73%|██████████████████████████████▋           | 19/26 [00:10<00:04,  1.69it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625       0.625       3.5999999 151.7973753]
#  77%|████████████████████████████████▎         | 20/26 [00:11<00:03,  1.63it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  150.52861008]
#  81%|█████████████████████████████████▉        | 21/26 [00:12<00:03,  1.57it/s]Modifying image pixdim from [0.625   0.625   3.60001 1.     ] to [  0.625        0.625        3.60000992 149.1610426 ]
#  85%|███████████████████████████████████▌      | 22/26 [00:12<00:02,  1.56it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  150.20609596]
#  88%|█████████████████████████████████████▏    | 23/26 [00:13<00:01,  1.55it/s]Modifying image pixdim from [0.6249998 0.625     3.5999987 1.       ] to [  0.62499983   0.625        3.59999877 153.34152766]
#  92%|██████████████████████████████████████▊   | 24/26 [00:14<00:01,  1.55it/s]Modifying image pixdim from [0.604167  0.6041667 3.999998  1.       ] to [  0.60416698   0.60416671   3.99999799 174.60244975]
#  96%|████████████████████████████████████████▍ | 25/26 [00:14<00:00,  1.65it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  160.84918933]
# 100%|██████████████████████████████████████████| 26/26 [00:15<00:00,  1.67it/s]

# %%
# ITKWidgets provide interactive 2D and 3D visualizations of ITK images, Pytorch/MONAI tensors, and multiple other image
#   surface, mesh, and point-cloud formats.   It is vital to verify inputs, intermediate results, and outputs using
#   a high-quality medical image aware viewer such as ITKWidgets with conducting deep learning research - otherwise days of
#   training can be wasted or new insights missed...
from itkwidgets import view

# The data loader provides access to training data.  Transforms are applied to the data as defined.  Intermediate results 
#   (e.g., prior to application of random transforms) are cached when possible to speed the generation of additional data.
data_dict = next(iter(train_data_loader))

# The itkwidget view command accepts multiple arguments to define 3D and 2D visualization parameters.  Here the first training
#   image is shown with its segmentation label shown as an overlay.   The user can swith between 2D and 3D views and specify
#   transfer functions, window and level settings, overlap opacity, crop regions, landmark locations, and much more.
view(image=data_dict["image"][0,0,:,:,:], label_image=data_dict["label"][0,0,:,:,:])
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, interpolation=False, point_sets=[], rendered_image=<itk.itkImageP…

# %%
import torch

# For this demo, we will illustrate how UNet (and any of the 20+ networks available in MONAI) can be easily specified
#   using a few parameters.
from monai.networks.nets import UNet

# This network will use Batch normalization, the Dice loss function commonly used in medical image segmentation performance
#   assessment, and a SlidingWindowInferer that partitions arbitrarily large images into sections that are streamed
#   individually to the GPU, to reduce GPU memory requirements.
from monai.networks.layers import Norm
from monai.losses import DiceLoss
from monai.inferers import SlidingWindowInferer

# A local GPU is assumed.
device = torch.device('cuda:0')

# The specification of a UNet architecture has been reduced to its essential parameters in a compact yet intuitive format
net = UNet(dimensions=3, in_channels=2, out_channels=2, channels=(16, 32, 64, 128, 256),
           strides=(2, 2, 2, 2), num_res_units=2, norm=Norm.BATCH).to(device)

# The background (0 value labels) are ignored in dice computation to focus performance assessment on the class of interest
loss = DiceLoss(to_onehot_y=True, softmax=True, include_background=False)

# Adam optimization from PyTorch (and other aspects of Pytorch) can be easily combined with MONAI workflows
opt = torch.optim.Adam(net.parameters(), 1e-4)

# The sliding windows overlap by 50%, and results from multiple windows are combined based on a gaussian weighting of their
#    distance from the center of each window.
inferer = SlidingWindowInferer((32, 128, 128), sw_batch_size=1, overlap=0.5, mode='gaussian')

# %%
# Engines provide training and inference workflows
from monai.engines import SupervisedTrainer

# Handlers are called when events occur during training and inference (e.g., between epochs)
from monai.handlers import StatsHandler, MeanDice

# Outstanding documentation on available transforms is online at https://docs.monai.io/en/latest/
from monai.transforms import AsDiscreteD

# Setup information-level logging
import sys
import logging
logging.basicConfig(stream=sys.stdout, level=logging.INFO)

# After passing data through the network to generate a prediction,  The unet's 2 outputs are converted to class labels via
#   argmax), the prediction and labels are compared by converting both to a 2-class, one-hot encoding that dice expects.
train_post_transform = Compose([
    AsDiscreteD(keys=["pred", "label"], argmax=(True, False), to_onehot=True, n_classes=2)
])

# After each epoch, report the loss function's value
train_handler = [
    StatsHandler(tag_name="train_loss", output_transform=lambda x: x["loss"]),
]

# Pass the network and optimization details to the training engine, and run for 20 epochs.
trainer = SupervisedTrainer(
    device=device,
    max_epochs=20,
    train_data_loader=train_data_loader,
    network=net,
    optimizer=opt,
    loss_function=loss,
    inferer=inferer,
    post_transform=train_post_transform,
    train_handlers=train_handler,
    key_train_metric={"train_meandice": MeanDice(include_background=False, output_transform=lambda x: (x["pred"], x["label"]))},
)

trainer.run()
# Out:
# INFO:ignite.engine.engine.SupervisedTrainer:Engine run resuming from iteration 0, epoch 0 until 20 epochs
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 1/26 -- train_loss: 0.9482
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 2/26 -- train_loss: 0.9663
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 3/26 -- train_loss: 0.9762
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 4/26 -- train_loss: 0.9622
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 5/26 -- train_loss: 0.9616
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 6/26 -- train_loss: 0.9120
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 7/26 -- train_loss: 0.9308
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 8/26 -- train_loss: 0.8888
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 9/26 -- train_loss: 0.9272
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 10/26 -- train_loss: 0.9215
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 11/26 -- train_loss: 0.7864
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 12/26 -- train_loss: 0.9639
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 13/26 -- train_loss: 0.9114
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 14/26 -- train_loss: 0.9460
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 15/26 -- train_loss: 0.9061
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 16/26 -- train_loss: 0.9617
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 17/26 -- train_loss: 0.9134
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 18/26 -- train_loss: 0.8655
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 19/26 -- train_loss: 0.9569
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 20/26 -- train_loss: 0.9475
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 21/26 -- train_loss: 0.9118
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 22/26 -- train_loss: 0.9167
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 23/26 -- train_loss: 0.8597
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 24/26 -- train_loss: 0.8768
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 25/26 -- train_loss: 0.9083
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 1/20, Iter: 26/26 -- train_loss: 0.9287
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.10893620830029249
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[1] Metrics -- train_meandice: 0.1089
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.10893620830029249 at epoch: 1
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[1] Complete. Time taken: 00:00:59
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 1/26 -- train_loss: 0.8104
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 2/26 -- train_loss: 0.8977
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 3/26 -- train_loss: 0.9429
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 4/26 -- train_loss: 0.9010
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 5/26 -- train_loss: 0.9482
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 6/26 -- train_loss: 0.9108
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 7/26 -- train_loss: 0.8740
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 8/26 -- train_loss: 0.9543
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 9/26 -- train_loss: 0.8878
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 10/26 -- train_loss: 0.8321
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 11/26 -- train_loss: 0.8552
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 12/26 -- train_loss: 0.8233
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 13/26 -- train_loss: 0.9235
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 14/26 -- train_loss: 0.8735
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 15/26 -- train_loss: 0.8270
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 16/26 -- train_loss: 0.8975
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 17/26 -- train_loss: 0.6963
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 18/26 -- train_loss: 0.9208
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 19/26 -- train_loss: 0.8514
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 20/26 -- train_loss: 0.9116
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 21/26 -- train_loss: 0.8907
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 22/26 -- train_loss: 0.8423
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 23/26 -- train_loss: 0.8190
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 24/26 -- train_loss: 0.8742
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 25/26 -- train_loss: 0.8536
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 2/20, Iter: 26/26 -- train_loss: 0.8608
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.22877540109822384
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[2] Metrics -- train_meandice: 0.2288
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.22877540109822384 at epoch: 2
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[2] Complete. Time taken: 00:00:58
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 1/26 -- train_loss: 0.8966
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 2/26 -- train_loss: 0.9232
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 3/26 -- train_loss: 0.8860
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 4/26 -- train_loss: 0.7874
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 5/26 -- train_loss: 0.8782
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 6/26 -- train_loss: 0.8072
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 7/26 -- train_loss: 0.8757
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 8/26 -- train_loss: 0.7572
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 9/26 -- train_loss: 0.8258
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 10/26 -- train_loss: 0.8891
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 11/26 -- train_loss: 0.7439
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 12/26 -- train_loss: 0.8095
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 13/26 -- train_loss: 0.8819
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 14/26 -- train_loss: 0.9019
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 15/26 -- train_loss: 0.6665
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 16/26 -- train_loss: 0.7959
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 17/26 -- train_loss: 0.7290
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 18/26 -- train_loss: 0.8849
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 19/26 -- train_loss: 0.6481
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 20/26 -- train_loss: 0.7639
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 21/26 -- train_loss: 0.8827
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 22/26 -- train_loss: 0.7787
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 23/26 -- train_loss: 0.8252
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 24/26 -- train_loss: 0.8019
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 25/26 -- train_loss: 0.8367
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 3/20, Iter: 26/26 -- train_loss: 0.7133
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.3802880490055451
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[3] Metrics -- train_meandice: 0.3803
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.3802880490055451 at epoch: 3
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[3] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 1/26 -- train_loss: 0.8583
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 2/26 -- train_loss: 0.7269
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 3/26 -- train_loss: 0.8590
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 4/26 -- train_loss: 0.7752
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 5/26 -- train_loss: 0.8576
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 6/26 -- train_loss: 0.7154
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 7/26 -- train_loss: 0.8967
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 8/26 -- train_loss: 0.8653
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 9/26 -- train_loss: 0.7609
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 10/26 -- train_loss: 0.7315
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 11/26 -- train_loss: 0.9245
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 12/26 -- train_loss: 0.7526
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 13/26 -- train_loss: 0.7854
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 14/26 -- train_loss: 0.8166
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 15/26 -- train_loss: 0.8986
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 16/26 -- train_loss: 0.7786
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 17/26 -- train_loss: 0.8050
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 18/26 -- train_loss: 0.7177
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 19/26 -- train_loss: 0.8397
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 20/26 -- train_loss: 0.8926
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 21/26 -- train_loss: 0.7475
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 22/26 -- train_loss: 0.8815
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 23/26 -- train_loss: 0.6450
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 24/26 -- train_loss: 0.6884
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 25/26 -- train_loss: 0.4658
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 4/20, Iter: 26/26 -- train_loss: 0.6166
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.3866497329794444
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[4] Metrics -- train_meandice: 0.3866
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.3866497329794444 at epoch: 4
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[4] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 1/26 -- train_loss: 0.7013
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 2/26 -- train_loss: 0.7865
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 3/26 -- train_loss: 0.4479
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 4/26 -- train_loss: 0.7362
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 5/26 -- train_loss: 0.8441
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 6/26 -- train_loss: 0.5705
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 7/26 -- train_loss: 0.7090
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 8/26 -- train_loss: 0.8236
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 9/26 -- train_loss: 0.7616
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 10/26 -- train_loss: 0.6442
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 11/26 -- train_loss: 0.6829
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 12/26 -- train_loss: 0.7800
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 13/26 -- train_loss: 0.8120
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 14/26 -- train_loss: 0.6685
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 15/26 -- train_loss: 0.6482
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 16/26 -- train_loss: 0.6474
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 17/26 -- train_loss: 0.7376
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 18/26 -- train_loss: 0.6122
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 19/26 -- train_loss: 0.7741
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 20/26 -- train_loss: 0.5460
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 21/26 -- train_loss: 0.8109
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 22/26 -- train_loss: 0.5813
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 23/26 -- train_loss: 0.6504
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 24/26 -- train_loss: 0.4816
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 25/26 -- train_loss: 0.8317
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 5/20, Iter: 26/26 -- train_loss: 0.6326
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.5692675612293757
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[5] Metrics -- train_meandice: 0.5693
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.5692675612293757 at epoch: 5
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[5] Complete. Time taken: 00:00:58
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 1/26 -- train_loss: 0.7132
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 2/26 -- train_loss: 0.5372
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 3/26 -- train_loss: 0.6582
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 4/26 -- train_loss: 0.7590
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 5/26 -- train_loss: 0.6223
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 6/26 -- train_loss: 0.7603
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 7/26 -- train_loss: 0.6184
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 8/26 -- train_loss: 0.5560
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 9/26 -- train_loss: 0.3744
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 10/26 -- train_loss: 0.5205
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 11/26 -- train_loss: 0.5404
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 12/26 -- train_loss: 0.4530
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 13/26 -- train_loss: 0.6644
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 14/26 -- train_loss: 0.5674
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 15/26 -- train_loss: 0.7049
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 16/26 -- train_loss: 0.7623
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 17/26 -- train_loss: 0.7022
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 18/26 -- train_loss: 0.6031
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 19/26 -- train_loss: 0.7810
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 20/26 -- train_loss: 0.4916
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 21/26 -- train_loss: 0.5486
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 22/26 -- train_loss: 0.7002
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 23/26 -- train_loss: 0.5082
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 24/26 -- train_loss: 0.7419
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 25/26 -- train_loss: 0.6983
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 6/20, Iter: 26/26 -- train_loss: 0.5675
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.6509596888835614
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[6] Metrics -- train_meandice: 0.6510
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.6509596888835614 at epoch: 6
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[6] Complete. Time taken: 00:00:58
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 1/26 -- train_loss: 0.4949
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 2/26 -- train_loss: 0.6791
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 3/26 -- train_loss: 0.7093
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 4/26 -- train_loss: 0.4604
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 5/26 -- train_loss: 0.4876
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 6/26 -- train_loss: 0.4949
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 7/26 -- train_loss: 0.4165
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 8/26 -- train_loss: 0.8150
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 9/26 -- train_loss: 0.6108
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 10/26 -- train_loss: 0.5686
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 11/26 -- train_loss: 0.4570
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 12/26 -- train_loss: 0.6398
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 13/26 -- train_loss: 0.5069
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 14/26 -- train_loss: 0.4668
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 15/26 -- train_loss: 0.5493
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 16/26 -- train_loss: 0.2919
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 17/26 -- train_loss: 0.3950
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 18/26 -- train_loss: 0.6461
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 19/26 -- train_loss: 0.7109
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 20/26 -- train_loss: 0.6006
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 21/26 -- train_loss: 0.6067
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 22/26 -- train_loss: 0.5813
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 23/26 -- train_loss: 0.6291
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 24/26 -- train_loss: 0.4643
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 25/26 -- train_loss: 0.3465
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 7/20, Iter: 26/26 -- train_loss: 0.6471
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.7251511663198471
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[7] Metrics -- train_meandice: 0.7252
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.7251511663198471 at epoch: 7
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[7] Complete. Time taken: 00:01:01
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 1/26 -- train_loss: 0.4560
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 2/26 -- train_loss: 0.6356
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 3/26 -- train_loss: 0.6002
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 4/26 -- train_loss: 0.6199
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 5/26 -- train_loss: 0.4151
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 6/26 -- train_loss: 0.4040
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 7/26 -- train_loss: 0.4939
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 8/26 -- train_loss: 0.5283
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 9/26 -- train_loss: 0.3631
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 10/26 -- train_loss: 0.5811
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 11/26 -- train_loss: 0.5955
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 12/26 -- train_loss: 0.3734
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 13/26 -- train_loss: 0.4420
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 14/26 -- train_loss: 0.3411
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 15/26 -- train_loss: 0.3815
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 16/26 -- train_loss: 0.3243
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 17/26 -- train_loss: 0.6443
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 18/26 -- train_loss: 0.6159
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 19/26 -- train_loss: 0.3086
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 20/26 -- train_loss: 0.4315
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 21/26 -- train_loss: 0.7211
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 22/26 -- train_loss: 0.7783
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 23/26 -- train_loss: 0.4983
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 24/26 -- train_loss: 0.3262
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 25/26 -- train_loss: 0.4169
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 8/20, Iter: 26/26 -- train_loss: 0.6475
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.7286942922152005
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[8] Metrics -- train_meandice: 0.7287
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.7286942922152005 at epoch: 8
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[8] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 1/26 -- train_loss: 0.5362
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 2/26 -- train_loss: 0.6422
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 3/26 -- train_loss: 0.5099
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 4/26 -- train_loss: 0.4728
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 5/26 -- train_loss: 0.3954
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 6/26 -- train_loss: 0.5749
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 7/26 -- train_loss: 0.3695
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 8/26 -- train_loss: 0.2236
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 9/26 -- train_loss: 0.5144
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 10/26 -- train_loss: 0.5145
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 11/26 -- train_loss: 0.2891
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 12/26 -- train_loss: 0.3667
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 13/26 -- train_loss: 0.3509
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 14/26 -- train_loss: 0.3695
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 15/26 -- train_loss: 0.2880
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 16/26 -- train_loss: 0.3895
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 17/26 -- train_loss: 0.3510
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 18/26 -- train_loss: 0.5613
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 19/26 -- train_loss: 0.5509
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 20/26 -- train_loss: 0.4256
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 21/26 -- train_loss: 0.2934
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 22/26 -- train_loss: 0.3890
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 23/26 -- train_loss: 0.4745
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 24/26 -- train_loss: 0.5122
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 25/26 -- train_loss: 0.3864
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 9/20, Iter: 26/26 -- train_loss: 0.5361
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.7861886895619906
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[9] Metrics -- train_meandice: 0.7862
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.7861886895619906 at epoch: 9
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[9] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 1/26 -- train_loss: 0.4890
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 2/26 -- train_loss: 0.3262
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 3/26 -- train_loss: 0.4088
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 4/26 -- train_loss: 0.3762
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 5/26 -- train_loss: 0.3467
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 6/26 -- train_loss: 0.4308
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 7/26 -- train_loss: 0.2325
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 8/26 -- train_loss: 0.3203
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 9/26 -- train_loss: 0.2414
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 10/26 -- train_loss: 0.6076
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 11/26 -- train_loss: 0.5405
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 12/26 -- train_loss: 0.5216
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 13/26 -- train_loss: 0.4903
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 14/26 -- train_loss: 0.4553
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 15/26 -- train_loss: 0.3038
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 16/26 -- train_loss: 0.3113
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 17/26 -- train_loss: 0.1766
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 18/26 -- train_loss: 0.2739
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 19/26 -- train_loss: 0.5909
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 20/26 -- train_loss: 0.2224
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 21/26 -- train_loss: 0.3716
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 22/26 -- train_loss: 0.3934
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 23/26 -- train_loss: 0.3333
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 24/26 -- train_loss: 0.3165
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 25/26 -- train_loss: 0.2849
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 10/20, Iter: 26/26 -- train_loss: 0.2908
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.8060809465555044
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[10] Metrics -- train_meandice: 0.8061
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8060809465555044 at epoch: 10
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[10] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 1/26 -- train_loss: 0.3199
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 2/26 -- train_loss: 0.3222
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 3/26 -- train_loss: 0.3614
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 4/26 -- train_loss: 0.4728
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 5/26 -- train_loss: 0.2397
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 6/26 -- train_loss: 0.4345
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 7/26 -- train_loss: 0.2411
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 8/26 -- train_loss: 0.3601
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 9/26 -- train_loss: 0.3011
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 10/26 -- train_loss: 0.4668
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 11/26 -- train_loss: 0.5824
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 12/26 -- train_loss: 0.2451
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 13/26 -- train_loss: 0.3097
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 14/26 -- train_loss: 0.3487
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 15/26 -- train_loss: 0.3998
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 16/26 -- train_loss: 0.3890
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 17/26 -- train_loss: 0.4085
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 18/26 -- train_loss: 0.4661
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 19/26 -- train_loss: 0.2674
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 20/26 -- train_loss: 0.4964
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 21/26 -- train_loss: 0.2808
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 22/26 -- train_loss: 0.1726
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 23/26 -- train_loss: 0.5327
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 24/26 -- train_loss: 0.4147
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 25/26 -- train_loss: 0.2325
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 11/20, Iter: 26/26 -- train_loss: 0.4776
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[11] Metrics -- train_meandice: 0.7793
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8060809465555044 at epoch: 10
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[11] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 1/26 -- train_loss: 0.3580
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 2/26 -- train_loss: 0.2829
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 3/26 -- train_loss: 0.2771
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 4/26 -- train_loss: 0.3921
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 5/26 -- train_loss: 0.7425
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 6/26 -- train_loss: 0.2762
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 7/26 -- train_loss: 0.4358
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 8/26 -- train_loss: 0.4189
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 9/26 -- train_loss: 0.4137
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 10/26 -- train_loss: 0.3188
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 11/26 -- train_loss: 0.4135
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 12/26 -- train_loss: 0.4291
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 13/26 -- train_loss: 0.4817
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 14/26 -- train_loss: 0.3984
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 15/26 -- train_loss: 0.4028
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 16/26 -- train_loss: 0.4384
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 17/26 -- train_loss: 0.3497
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 18/26 -- train_loss: 0.3028
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 19/26 -- train_loss: 0.2790
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 20/26 -- train_loss: 0.2266
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 21/26 -- train_loss: 0.2060
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 22/26 -- train_loss: 0.3004
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 23/26 -- train_loss: 0.3303
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 24/26 -- train_loss: 0.2238
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 25/26 -- train_loss: 0.3124
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 12/20, Iter: 26/26 -- train_loss: 0.2291
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[12] Metrics -- train_meandice: 0.7726
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8060809465555044 at epoch: 10
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[12] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 1/26 -- train_loss: 0.4522
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 2/26 -- train_loss: 0.5094
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 3/26 -- train_loss: 0.1777
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 4/26 -- train_loss: 0.2953
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 5/26 -- train_loss: 0.2627
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 6/26 -- train_loss: 0.2506
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 7/26 -- train_loss: 0.4023
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 8/26 -- train_loss: 0.2544
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 9/26 -- train_loss: 0.4051
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 10/26 -- train_loss: 0.4761
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 11/26 -- train_loss: 0.4393
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 12/26 -- train_loss: 0.3144
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 13/26 -- train_loss: 0.4824
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 14/26 -- train_loss: 0.5685
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 15/26 -- train_loss: 0.2255
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 16/26 -- train_loss: 0.1973
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 17/26 -- train_loss: 0.3462
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 18/26 -- train_loss: 0.2324
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 19/26 -- train_loss: 0.3013
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 20/26 -- train_loss: 0.4542
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 21/26 -- train_loss: 0.2705
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 22/26 -- train_loss: 0.3410
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 23/26 -- train_loss: 0.4756
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 24/26 -- train_loss: 0.3829
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 25/26 -- train_loss: 0.2420
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 13/20, Iter: 26/26 -- train_loss: 0.2476
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[13] Metrics -- train_meandice: 0.7785
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8060809465555044 at epoch: 10
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[13] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 1/26 -- train_loss: 0.4285
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 2/26 -- train_loss: 0.1833
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 3/26 -- train_loss: 0.3656
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 4/26 -- train_loss: 0.2176
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 5/26 -- train_loss: 0.5253
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 6/26 -- train_loss: 0.2586
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 7/26 -- train_loss: 0.3552
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 8/26 -- train_loss: 0.3627
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 9/26 -- train_loss: 0.2230
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 10/26 -- train_loss: 0.2296
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 11/26 -- train_loss: 0.3454
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 12/26 -- train_loss: 0.2459
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 13/26 -- train_loss: 0.3168
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 14/26 -- train_loss: 0.3472
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 15/26 -- train_loss: 0.2419
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 16/26 -- train_loss: 0.2015
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 17/26 -- train_loss: 0.1993
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 18/26 -- train_loss: 0.2095
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 19/26 -- train_loss: 0.3277
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 20/26 -- train_loss: 0.3800
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 21/26 -- train_loss: 0.2096
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 22/26 -- train_loss: 0.3261
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 23/26 -- train_loss: 0.2078
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 24/26 -- train_loss: 0.3159
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 25/26 -- train_loss: 0.2288
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 14/20, Iter: 26/26 -- train_loss: 0.3688
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.8147934468892905
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[14] Metrics -- train_meandice: 0.8148
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8147934468892905 at epoch: 14
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[14] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 1/26 -- train_loss: 0.3846
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 2/26 -- train_loss: 0.2131
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 3/26 -- train_loss: 0.2609
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 4/26 -- train_loss: 0.2504
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 5/26 -- train_loss: 0.4348
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 6/26 -- train_loss: 0.1824
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 7/26 -- train_loss: 0.3828
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 8/26 -- train_loss: 0.1815
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 9/26 -- train_loss: 0.2481
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 10/26 -- train_loss: 0.2880
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 11/26 -- train_loss: 0.2629
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 12/26 -- train_loss: 0.2600
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 13/26 -- train_loss: 0.3394
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 14/26 -- train_loss: 0.3279
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 15/26 -- train_loss: 0.2227
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 16/26 -- train_loss: 0.2360
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 17/26 -- train_loss: 0.2584
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 18/26 -- train_loss: 0.3180
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 19/26 -- train_loss: 0.1959
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 20/26 -- train_loss: 0.3175
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 21/26 -- train_loss: 0.5691
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 22/26 -- train_loss: 0.3186
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 23/26 -- train_loss: 0.2112
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 24/26 -- train_loss: 0.1744
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 25/26 -- train_loss: 0.1847
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 15/20, Iter: 26/26 -- train_loss: 0.3288
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[15] Metrics -- train_meandice: 0.8005
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8147934468892905 at epoch: 14
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[15] Complete. Time taken: 00:00:58
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 1/26 -- train_loss: 0.1834
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 2/26 -- train_loss: 0.1749
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 3/26 -- train_loss: 0.2695
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 4/26 -- train_loss: 0.1903
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 5/26 -- train_loss: 0.2709
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 6/26 -- train_loss: 0.3150
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 7/26 -- train_loss: 0.2707
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 8/26 -- train_loss: 0.3090
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 9/26 -- train_loss: 0.3267
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 10/26 -- train_loss: 0.2006
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 11/26 -- train_loss: 0.1925
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 12/26 -- train_loss: 0.3183
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 13/26 -- train_loss: 0.1603
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 14/26 -- train_loss: 0.2090
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 15/26 -- train_loss: 0.2222
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 16/26 -- train_loss: 0.1974
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 17/26 -- train_loss: 0.1443
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 18/26 -- train_loss: 0.1791
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 19/26 -- train_loss: 0.4650
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 20/26 -- train_loss: 0.1786
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 21/26 -- train_loss: 0.2179
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 22/26 -- train_loss: 0.1480
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 23/26 -- train_loss: 0.3529
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 24/26 -- train_loss: 0.1717
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 25/26 -- train_loss: 0.2731
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 16/20, Iter: 26/26 -- train_loss: 0.1883
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.844629902106065
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[16] Metrics -- train_meandice: 0.8446
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.844629902106065 at epoch: 16
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[16] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 1/26 -- train_loss: 0.1692
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 2/26 -- train_loss: 0.2829
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 3/26 -- train_loss: 0.3210
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 4/26 -- train_loss: 0.2889
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 5/26 -- train_loss: 0.1991
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 6/26 -- train_loss: 0.1714
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 7/26 -- train_loss: 0.2485
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 8/26 -- train_loss: 0.2553
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 9/26 -- train_loss: 0.1488
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 10/26 -- train_loss: 0.1996
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 11/26 -- train_loss: 0.1328
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 12/26 -- train_loss: 0.1780
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 13/26 -- train_loss: 0.2820
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 14/26 -- train_loss: 0.1836
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 15/26 -- train_loss: 0.1300
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 16/26 -- train_loss: 0.2171
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 17/26 -- train_loss: 0.3684
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 18/26 -- train_loss: 0.3124
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 19/26 -- train_loss: 0.2632
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 20/26 -- train_loss: 0.3022
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 21/26 -- train_loss: 0.1628
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 22/26 -- train_loss: 0.1809
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 23/26 -- train_loss: 0.1584
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 24/26 -- train_loss: 0.1734
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 25/26 -- train_loss: 0.2322
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 17/20, Iter: 26/26 -- train_loss: 0.1968
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.8503999205736014
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[17] Metrics -- train_meandice: 0.8504
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8503999205736014 at epoch: 17
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[17] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 1/26 -- train_loss: 0.2167
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 2/26 -- train_loss: 0.2125
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 3/26 -- train_loss: 0.2464
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 4/26 -- train_loss: 0.2565
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 5/26 -- train_loss: 0.1422
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 6/26 -- train_loss: 0.1486
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 7/26 -- train_loss: 0.1682
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 8/26 -- train_loss: 0.1302
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 9/26 -- train_loss: 0.2520
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 10/26 -- train_loss: 0.2705
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 11/26 -- train_loss: 0.1142
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 12/26 -- train_loss: 0.1158
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 13/26 -- train_loss: 0.2101
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 14/26 -- train_loss: 0.1481
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 15/26 -- train_loss: 0.1408
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 16/26 -- train_loss: 0.2215
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 17/26 -- train_loss: 0.1840
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 18/26 -- train_loss: 0.2301
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 19/26 -- train_loss: 0.2720
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 20/26 -- train_loss: 0.1528
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 21/26 -- train_loss: 0.1556
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 22/26 -- train_loss: 0.1578
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 23/26 -- train_loss: 0.1779
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 24/26 -- train_loss: 0.2352
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 25/26 -- train_loss: 0.1616
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 18/20, Iter: 26/26 -- train_loss: 0.2669
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.8626898229122162
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[18] Metrics -- train_meandice: 0.8627
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8626898229122162 at epoch: 18
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[18] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 1/26 -- train_loss: 0.0974
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 2/26 -- train_loss: 0.1801
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 3/26 -- train_loss: 0.1437
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 4/26 -- train_loss: 0.2251
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 5/26 -- train_loss: 0.1837
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 6/26 -- train_loss: 0.1778
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 7/26 -- train_loss: 0.1872
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 8/26 -- train_loss: 0.1545
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 9/26 -- train_loss: 0.1479
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 10/26 -- train_loss: 0.2766
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 11/26 -- train_loss: 0.2078
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 12/26 -- train_loss: 0.2082
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 13/26 -- train_loss: 0.2101
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 14/26 -- train_loss: 0.1799
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 15/26 -- train_loss: 0.1956
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 16/26 -- train_loss: 0.2727
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 17/26 -- train_loss: 0.1970
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 18/26 -- train_loss: 0.2272
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 19/26 -- train_loss: 0.2027
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 20/26 -- train_loss: 0.1297
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 21/26 -- train_loss: 0.2268
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 22/26 -- train_loss: 0.1630
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 23/26 -- train_loss: 0.1226
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 24/26 -- train_loss: 0.2581
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 25/26 -- train_loss: 0.1337
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 19/20, Iter: 26/26 -- train_loss: 0.2007
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.865698727277609
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[19] Metrics -- train_meandice: 0.8657
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.865698727277609 at epoch: 19
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[19] Complete. Time taken: 00:00:56
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 1/26 -- train_loss: 0.2481
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 2/26 -- train_loss: 0.2126
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 3/26 -- train_loss: 0.1450
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 4/26 -- train_loss: 0.1647
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 5/26 -- train_loss: 0.2249
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 6/26 -- train_loss: 0.1950
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 7/26 -- train_loss: 0.1705
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 8/26 -- train_loss: 0.1265
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 9/26 -- train_loss: 0.1075
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 10/26 -- train_loss: 0.1914
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 11/26 -- train_loss: 0.1728
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 12/26 -- train_loss: 0.1468
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 13/26 -- train_loss: 0.1443
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 14/26 -- train_loss: 0.2752
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 15/26 -- train_loss: 0.1138
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 16/26 -- train_loss: 0.1102
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 17/26 -- train_loss: 0.1836
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 18/26 -- train_loss: 0.1742
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 19/26 -- train_loss: 0.2032
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 20/26 -- train_loss: 0.1947
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 21/26 -- train_loss: 0.2155
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 22/26 -- train_loss: 0.1116
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 23/26 -- train_loss: 0.1533
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 24/26 -- train_loss: 0.2515
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 25/26 -- train_loss: 0.1356
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch: 20/20, Iter: 26/26 -- train_loss: 0.2342
# INFO:ignite.engine.engine.SupervisedTrainer:Got new best metric of train_meandice: 0.8698416856619028
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[20] Metrics -- train_meandice: 0.8698
# INFO:ignite.engine.engine.SupervisedTrainer:Key metric: train_meandice best value: 0.8698416856619028 at epoch: 20
# INFO:ignite.engine.engine.SupervisedTrainer:Epoch[20] Complete. Time taken: 00:00:57
# INFO:ignite.engine.engine.SupervisedTrainer:Engine run complete. Time taken: 00:19:00

# %%
from monai.transforms import \
    ActivationsD, KeepLargestConnectedComponentD
from monai.handlers import SegmentationSaver
from monai.engines import SupervisedEvaluator
from monai.inferers import SlidingWindowInferer
from ignite.metrics import Accuracy

# For validation, the Decathlon dataset only provides images (no labels), and we do not want to conduct random rotations - we
#   should only process the raw data, albeit resampled to isotropic voxels to match the training data's resolution
val_transforms = Compose([
    LoadImageD(keys=["image"]),
    AsChannelFirstD("image"),
    SpacingD(keys=["image"], pixdim=(1., 1., 1.), mode=('bilinear')),
    OrientationD(keys=["image"], axcodes='RAS'),
    ScaleIntensityD(keys="image"),
    ToTensorD(keys=["image"]),
])

# After a validation image is passed through the unet, we use argmax to convert from one-hot encoding to a single label image.
#   Additionally, we use the "KeepLargestConnectedComponent" filter to eliminate pixel label noise
val_post_transform = Compose([
    AsDiscreteD(keys=["pred"], argmax=True),
    KeepLargestConnectedComponentD(keys=["pred"], applied_labels=[1], connectivity=1, independent=False)
])

# Here we defined the validation dataset, from the Decathlon challenge, with minimal transforms applied.
val_dataset = DecathlonDataset(root_dir="./", task="Task05_Prostate", section="test", transform=val_transforms, download=True)

# The validation is downloaded, if it hasn't been already, as specified by the validation dataset.
val_data_loader = DataLoader(val_dataset, batch_size=1, num_workers=0)

# The segmentation results (predictions) from the unet will be saved to the local filesystem
output_dir = "./runs/"

# A MONAI handler is called after each validation image / batch is processed, to save the results.
val_handler = [
    StatsHandler(output_transform=lambda x: None),
    SegmentationSaver(
        output_dir=output_dir,
        batch_transform=lambda batch: batch["image_meta_dict"],
        output_transform=lambda output: output["pred"],
    ),
]

# The validation data loader, the already trained network, sliding window inferer, post transform, and handler are passed
#   to the inference engine.
evaluator = SupervisedEvaluator(
    device=device,
    val_data_loader=val_data_loader,
    network=net,
    inferer=inferer,
    post_transform=val_post_transform,
    val_handlers=val_handler,
)

evaluator.run()
# Out:
#   0%|                                                   | 0/16 [00:00<?, ?it/s]
# Verified 'Task05_Prostate.tar', md5: 35138f08b1efaef89d7424d2bcc928db.
# file ./Task05_Prostate.tar exists, skip downloading.
# extracted file ./Task05_Prostate exists, skip extracting.
# Modifying image pixdim from [0.6       0.5999997 3.999998  1.       ] to [  0.60000002   0.59999975   3.99999799 146.48690756]
#   6%|██▋                                        | 1/16 [00:00<00:04,  3.02it/s]Modifying image pixdim from [0.6       0.6000002 3.9999998 1.       ] to [  0.60000002   0.60000021   3.9999998  157.0444173 ]
#  12%|█████▍                                     | 2/16 [00:00<00:04,  3.12it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  145.74121012]
#  19%|████████                                   | 3/16 [00:01<00:04,  2.86it/s]Modifying image pixdim from [0.6        0.60000014 4.0000005  1.        ] to [  0.60000002   0.60000017   4.00000043 159.82709003]
#  25%|██████████▊                                | 4/16 [00:01<00:03,  3.01it/s]Modifying image pixdim from [0.625   0.625   3.60001 1.     ] to [  0.625        0.625        3.60000992 176.39125911]
#  31%|█████████████▍                             | 5/16 [00:01<00:03,  2.83it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  163.50319947]
#  38%|████████████████▏                          | 6/16 [00:02<00:03,  2.63it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  149.73363966]
#  44%|██████████████████▊                        | 7/16 [00:02<00:03,  2.56it/s]Modifying image pixdim from [0.625   0.625   3.60001 1.     ] to [  0.625        0.625        3.60000992 162.47222301]
#  50%|█████████████████████▌                     | 8/16 [00:03<00:03,  2.53it/s]Modifying image pixdim from [0.6        0.60000014 4.0000105  1.        ] to [  0.60000002   0.60000017   4.00001045 157.49050012]
#  56%|████████████████████████▏                  | 9/16 [00:03<00:02,  2.60it/s]Modifying image pixdim from [0.6249997 0.6249998 3.6000001 1.       ] to [  0.62499968   0.62499985   3.60000005 145.39638806]
#  62%|██████████████████████████▎               | 10/16 [00:03<00:02,  2.60it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  187.26353776]
#  69%|████████████████████████████▉             | 11/16 [00:04<00:01,  2.58it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  152.89398425]
#  75%|███████████████████████████████▌          | 12/16 [00:04<00:01,  2.55it/s]Modifying image pixdim from [0.625      0.62500006 3.600011   1.        ] to [  0.62500002   0.62500007   3.60001102 191.90123228]
#  81%|██████████████████████████████████▏       | 13/16 [00:04<00:01,  2.55it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  169.09585369]
#  88%|████████████████████████████████████▊     | 14/16 [00:05<00:00,  2.62it/s]Modifying image pixdim from [0.6250002 0.6250002 3.6       1.       ] to [  0.62500018   0.62500018   3.5999999  163.78888346]
#  94%|███████████████████████████████████████▍  | 15/16 [00:05<00:00,  2.59it/s]Modifying image pixdim from [0.625 0.625 3.6   1.   ] to [  0.625        0.625        3.5999999  159.46452616]
# 100%|██████████████████████████████████████████| 16/16 [00:06<00:00,  2.64it/s]
# INFO:ignite.engine.engine.SupervisedEvaluator:Engine run resuming from iteration 0, epoch 0 until 1 epochs
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:saved all the model outputs into files.
# INFO:ignite.engine.engine.SupervisedEvaluator:Epoch[1] Complete. Time taken: 00:00:06
# INFO:ignite.engine.engine.SupervisedEvaluator:Engine run complete. Time taken: 00:00:06

# %%
# Once the validation data has been processed and the predicted segmentations have been saved to disk, we can use
#   ITK and ITKWidgets to read and interactively explore the validation images with predicted segmentations overlaid...

import glob
import os

import itk

from itkwidgets import view

root_dir = "./"
output_dir = "./runs/"

imList=sorted(glob.glob(os.path.join(root_dir, "Task05_Prostate/imagesTs", "*.nii.gz")))
segList=sorted(glob.glob(os.path.join(output_dir, "*", "*.nii.gz")))

im = itk.imread(imList[0])
seg = itk.imread(segList[0])

view(image=im[0,:,:,:], label_image=seg)
# Out:
# Viewer(geometries=[], gradient_opacity=0.22, interpolation=False, point_sets=[], rendered_image=<itk.itkImageP…
